# %% [markdown]
# Programa de ML para predecir si un paciente tiene diabetes o no. Dataset obtenido de https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database?select=diabetes.csv. SON TODO MUJERES DE UNA CIERTA RAZA.

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:\\Users\\alvar\\OneDrive\\Escritorio\\PROYECTOS\\Python\\MLJupyter\\diabetes.csv")

# %% [markdown]
# ## Gestión inicial de datos

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# Si es "1" es que tiene diabetes, "0" si no la tiene.

# %% [markdown]
# - La DPF es una función relacionada con el número de familiares afectados por diabetes, el grado de parentesco de estos afectados con el paciente, y el tamaño de la familia.
#
# - El BMI en inglés es el IMC en español.
#
# - La SkinThickness se refiere al espesor del pliegue cutáneo tricipital: es una medida en milímetros (mm), se toma con un plicómetro en la parte posterior del brazo (tríceps) y representa la cantidad de grasa subcutánea de una persona.

# %% [markdown]
# LOS VALORES NULOS SIGNIFICAN QUE FALTA EL DATO (excepto en las columnas de pregnancies y outcome).

# %% [markdown]
# ## Tratamiento de datos

# %% [markdown]
# Aquí separo el dataset en y, X.

# %%
# y_data = data.Outcome
# X_data = data[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']]

# %% [markdown]
# Aquí miro el tamaño de la tabla de datos y la cantidad de 0's que aparecen en cada tabla.

# %%
# Shape of training data (num_rows, num_columns)
print(data.shape)

(data == 0).sum()
# Out:
# (768, 9)
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %% [markdown]
# Obviamente no nos importa que en Pregnancies o en Outcome haya un cero. Vamos a tener que imputar las columnas que sí que tienen 0's (G, BP, ST, I, BMI).

# %% [markdown]
# Vamos a ver también si hay algún hueco vacío "NaN" en esta tabla de datos:

# %%
# Number of missing values in each column of training data
missing_val_count_by_column_train = (data.isnull().sum())
print(missing_val_count_by_column_train[missing_val_count_by_column_train > 0])
# Out:
# Series([], dtype: int64)

# %% [markdown]
# NO HAY HUECOS VACÍOS.

# %% [markdown]
# Antes de imputar datos vamos a estudiar la correlación que hay entre ellos para saber que ténica de imputación usar. La correlaciones van entre -1 y 1 tal que:
# - Correlación positiva: Cuando una de las variables aumenta la otra tiende a aumentar también.
# - Correlación negativa:  Cuando una de las variables aumenta la otra tiende a disminuir.
# - Correlación 0: No hay ninguna relación lineal entre variables.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
sns.heatmap(data.corr(), annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# Hay una fuerte correlación positiva entre Outcome,Insulin y Glucose, como es lógico, así que podemos imputar la columna de Glucose con la mediana separando por Outcomes (No imputamos con Insulin ya que esta columna está muy vacía).

# %%
# Calcular la mediana de Glucose ignorando ceros
median_glucose = data.loc[data["Glucose"] != 0].groupby("Outcome")["Glucose"].median()

# imputo los ceros
data["Glucose"] = data["Glucose"].mask(data["Glucose"] == 0, data["Outcome"].map(median_glucose))

# %% [markdown]
# Confirmamos que la Glucose ha sido imputada.

# %%
(data == 0).sum()
# Out:
# Pregnancies                 111
# Glucose                       0
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %% [markdown]
# Para la columna de BMI podemos rellenar los 0's con la mediana y ya está (solo son 11 ceros de 768 datos).

# %%
# Calcular la mediana ignorando los ceros
median_BMI = data.loc[data["BMI"] != 0, "BMI"].median()

# Reemplazar ceros por la mediana
data["BMI"] = data["BMI"].replace(0, median_BMI)

# %% [markdown]
# Confirmamos que el BMI ha sido imputado:

# %%
(data == 0).sum()
# Out:
# Pregnancies                 111
# Glucose                       0
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                           0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %% [markdown]
# Vemos que la BP está directamente relacionada con Age y BMI, a si que podemos imputar con la mediana los huecos con 0's y clasificar por edades y BMI. Lo que pasa es que Age y BMI es un rango continuo, a si que hay que clasificar por bines. Para ello hay que ver los rangos que hay que tomar.

# %%
print('Age mínimo:',data['Age'].min())
print('Age máximo:',data['Age'].max())

print('BMI mínimo:',data['BMI'].min())
print('BMI máximo:',data['BMI'].max())
# Out:
# Age mínimo: 21
# Age máximo: 81
# BMI mínimo: 18.2
# BMI máximo: 67.1

# %% [markdown]
# Podemos hacer bines de 10 en 10, desde 20 hasta 80. Si Age = 21, entonces Age_bin = 0; si Age = 34, Age_bin = 1; etc.

# %%
data["Age_bin"] = pd.cut(data["Age"], bins=[20,30,40,50,60,70,80], labels=False)
data["BMI_bin"] = pd.cut(data["BMI"], bins=[15,25,35,45,55,65], labels=False)

# Calcular mediana de BP por grupo
median_BP = (data[data["BloodPressure"] != 0].groupby(["Age_bin", "BMI_bin"])["BloodPressure"].median())

# Función para imputar
def fill_BP(row):
    if row["BloodPressure"] == 0:
        # .get devuelve la mediana del bin o la mediana global si no existe
        return median_BP.get((row["Age_bin"], row["BMI_bin"]), data["BloodPressure"].median())
    else:
        return row["BloodPressure"]

# Aplicar imputación
data["BloodPressure"] = data.apply(fill_BP, axis=1)

# %%
(data == 0).sum()
# Out:
# Pregnancies                 111
# Glucose                       0
# BloodPressure                 0
# SkinThickness               227
# Insulin                     374
# BMI                           0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# Age_bin                     417
# BMI_bin                     112
# dtype: int64

# %% [markdown]
# Vamos a ver si ha cambiado algo del heatmap:

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(), annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# ## Tratamiento de SkinThickness e Insulin

# %%
print("Número de filas con ST e Insulin = 0:", ((data["SkinThickness"] == 0) & (data["Insulin"] == 0)).sum() )
# Out:
# Número de filas con ST e Insulin = 0: 227

# %% [markdown]
# Todas las filas en las que ST es 0, en Insulin también hay un cero. Tal vez lo mejor sea quitar todas estas filas para evitar suponer cosas.

# %%
data = data[~((data["SkinThickness"] == 0) & (data["Insulin"] == 0))]

# %%
(data == 0).sum()
# Out:
# Pregnancies                  79
# Glucose                       0
# BloodPressure                 0
# SkinThickness                 0
# Insulin                     147
# BMI                           0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     361
# Age_bin                     327
# BMI_bin                      65
# dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(), annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# Como era de esperar, al quitar los dobles ceros hemos obtenido una correlación mayor entre  insulina y la glucosa.

# %% [markdown]
# Tal vez podamos imputar la Insulin con la Glucose teniendo en cuenta esta fuerte correlación positiva.

# %%
print('Glucose mínimo:',data['Glucose'].min())
print('Glucose máximo:',data['Glucose'].max())
# Out:
# Glucose mínimo: 56
# Glucose máximo: 199

# %%
data["Glucose_bin"] = pd.cut(data["Glucose"], bins=[50,75,100,125,150,175], labels=False)

# Calcular mediana de Insul por grupo
median_Insul = (data[data["Insulin"] != 0].groupby(["Glucose_bin"])["Insulin"].median())

# Función para imputar
def fill_Insul(row):
    if row["Insulin"] == 0:
        # .get devuelve la mediana del bin o la mediana global si no existe
        return median_Insul.get((row["Glucose_bin"]), data["Insulin"].median())
    else:
        return row["Insulin"]

# Aplicar imputación
data["Insulin"] = data.apply(fill_Insul, axis=1)

# %%
(data == 0).sum()
# Out:
# Pregnancies                  79
# Glucose                       0
# BloodPressure                 0
# SkinThickness                 0
# Insulin                       0
# BMI                           0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     361
# Age_bin                     327
# BMI_bin                      65
# Glucose_bin                  16
# dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(), annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# ## Normalización de los datos

# %%
from sklearn.preprocessing import MinMaxScaler #Para normalizar los datos entre 0 y 1

# Selecciona solo columnas numéricas
cols = data.select_dtypes(include=['float64', 'int64']).columns

# Inicializa el scaler
scaler = MinMaxScaler()

# Escala las columnas y reemplaza en el DataFrame
data[cols] = scaler.fit_transform(data[cols])

# %% [markdown]
# ## Decision Tree

# %%
X_data = data[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','Age','DiabetesPedigreeFunction']]
y_data = data.Outcome

# %%
from sklearn.model_selection import train_test_split

# Dividimos el train original en train + valid
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2, random_state=42)
#test_size = 0.1 implica que el 10% de X_data va para X_valid (test)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

# Modelo base
#rf = DecisionTreeClassifier(random_state=42)

# Espacio de hiperparámetros
#param_dist = {
#    "max_depth": randint(3, 30),               # profundidad máxima
#    "min_samples_split": randint(2, 20),       # mínimo de muestras para dividir
#    "min_samples_leaf": randint(1, 20),        # mínimo de muestras en una hoja
#    "max_features": ["sqrt", "log2", None],    # número de features a usar
#    "criterion": ["gini", "entropy", "log_loss"],  # criterio de impureza
#    "max_leaf_nodes": randint(10, 1000)         # máximo número de hojas por árbol
#}

# Configuración de RandomizedSearchCV
#random_search = RandomizedSearchCV(
#    estimator=rf,
#    param_distributions=param_dist,
#    n_iter=50,              # número de combinaciones a probar
#    cv=5,                   # validación cruzada
#    scoring="accuracy",     # métrica de evaluación
#    random_state=42,
#    n_jobs=-1,              # usar todos los núcleos disponibles
#    verbose=1
#)

# Entrenamiento
#random_search.fit(X_train, y_train)

# Resultados
#print("Mejores hiperparámetros:", random_search.best_params_)
#print("Mejor score:", random_search.best_score_)

# %%
diabetes_dtmodel = DecisionTreeClassifier(
    max_leaf_nodes=1000,
    random_state=1,
    criterion='entropy',
    max_depth=5,
    min_samples_split=3,
    min_samples_leaf=5,
)

diabetes_dtmodel.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, max_leaf_nodes=1000,
#                        min_samples_leaf=5, min_samples_split=3, random_state=1)

# %%
predictions_dtmodel = diabetes_dtmodel.predict(X_test)

from sklearn.metrics import accuracy_score

# Suponiendo que y_test y predictions son arrays/listas
accuracy_rfmodel = accuracy_score(y_test, predictions_dtmodel) * 100
print(f"Porcentaje de aciertos: {accuracy_rfmodel:.2f}%")
# Out:
# Porcentaje de aciertos: 72.48%

# %% [markdown]
# ## XGboost

# %%
# Dividimos el train original en train + valid
X_train_new, X_valid, y_train_new, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
#from xgboost import XGBClassifier
#from sklearn.model_selection import RandomizedSearchCV
#from scipy.stats import randint, uniform

# Modelo base
#xgb = XGBClassifier(
#    random_state=42,
#    use_label_encoder=False,
#    eval_metric="logloss"   # evita warnings
#)

# Espacio de hiperparámetros
#param_dist = {
#    "n_estimators": randint(100, 1000),        # número de árboles
#    "max_depth": randint(3, 15),               # profundidad máxima
#    "learning_rate": uniform(0.01, 0.3),       # tasa de aprendizaje
#    "subsample": uniform(0.6, 0.4),            # proporción de muestras
#    "colsample_bytree": uniform(0.6, 0.4),     # proporción de features
#    "gamma": uniform(0, 5),                    # regularización mínima para dividir
#    "min_child_weight": randint(1, 10),        # peso mínimo de hojas
#    "scale_pos_weight": [1, 2, 5, 10]          # útil si las clases están desbalanceadas
#}

# Configuración de RandomizedSearchCV
#random_search = RandomizedSearchCV(
#    estimator=xgb,
#    param_distributions=param_dist,
#    n_iter=50,               # número de combinaciones a probar
#    scoring="f1",            # mejor que accuracy en problemas médicos
#    cv=5,                    # validación cruzada
#    verbose=1,
#    random_state=42,
#    n_jobs=-1
#)

# Entrenar
#random_search.fit(X_train_new, y_train_new)

# Resultados
#print("Mejores hiperparámetros:", random_search.best_params_)
#print("Mejor score:", random_search.best_score_)

# %%
from xgboost import XGBClassifier

diabetes_xgmodel = XGBClassifier(
    n_estimators=575,        # número de árboles
    learning_rate=0.05,      # tamaño de los pasos de boosting
    max_depth=8,             # profundidad máxima de cada árbol
    subsample=0.9,           # fracción de datos por árbol
    colsample_bytree=0.7,    # fracción de features por árbol
    use_label_encoder=False,
    eval_metric="logloss",
    early_stopping_rounds=50, 
    verbose=False,
    objective="binary:logistic",
    min_child_weight= 7,
    gamma = 4)

diabetes_xgmodel.fit(X_train_new, y_train_new, eval_set=[(X_valid, y_valid)])
# Out:
# [0]	validation_0-logloss:0.59701
# [1]	validation_0-logloss:0.59051
# [2]	validation_0-logloss:0.57929
# [3]	validation_0-logloss:0.56460
# [4]	validation_0-logloss:0.55685
# [5]	validation_0-logloss:0.54795
# [6]	validation_0-logloss:0.53886
# [7]	validation_0-logloss:0.53268
# [8]	validation_0-logloss:0.52741
# [9]	validation_0-logloss:0.52132
# [10]	validation_0-logloss:0.51808
# [11]	validation_0-logloss:0.51421
# [12]	validation_0-logloss:0.50799
# [13]	validation_0-logloss:0.50209
# [14]	validation_0-logloss:0.50151
# [15]	validation_0-logloss:0.49552
# [16]	validation_0-logloss:0.49041
# [17]	validation_0-logloss:0.48590
# [18]	validation_0-logloss:0.48167
# [19]	validation_0-logloss:0.47754
# [20]	validation_0-logloss:0.47589
# [21]	validation_0-logloss:0.47270
# [22]	validation_0-logloss:0.46867
# [23]	validation_0-logloss:0.46640
# [24]	validation_0-logloss:0.46064
# [25]	validation_0-logloss:0.46029
# [26]	validation_0-logloss:0.45561
# [27]	validation_0-logloss:0.45281
# [28]	validation_0-logloss:0.45043
# [29]	validation_0-logloss:0.44894
# [30]	validation_0-logloss:0.44708
# [31]	validation_0-logloss:0.44538
# [32]	validation_0-logloss:0.44174
# [33]	validation_0-logloss:0.44030
# [34]	validation_0-logloss:0.43784
# [35]	validation_0-logloss:0.43802
# [36]	validation_0-logloss:0.43705
# [37]	validation_0-logloss:0.43530
# [38]	validation_0-logloss:0.43429
# [39]	validation_0-logloss:0.43346
# [40]	validation_0-logloss:0.43252
# [41]	validation_0-logloss:0.42906
# [42]	validation_0-logloss:0.42749
# [43]	validation_0-logloss:0.42545
# [44]	validation_0-logloss:0.42448
# [45]	validation_0-logloss:0.42425
# [46]	validation_0-logloss:0.42591
# [47]	validation_0-logloss:0.42545
# [48]	validation_0-logloss:0.42477
# [49]	validation_0-logloss:0.42392
# [50]	validation_0-logloss:0.42288
# [51]	validation_0-logloss:0.42184
# [52]	validation_0-logloss:0.42112
# c:\Users\alvar\anaconda3\Lib\site-packages\xgboost\callback.py:386: UserWarning: [20:01:59] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder", "verbose" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [53]	validation_0-logloss:0.42172
# [54]	validation_0-logloss:0.42200
# [55]	validation_0-logloss:0.42204
# [56]	validation_0-logloss:0.42093
# [57]	validation_0-logloss:0.42227
# [58]	validation_0-logloss:0.42205
# [59]	validation_0-logloss:0.42157
# [60]	validation_0-logloss:0.42067
# [61]	validation_0-logloss:0.42064
# [62]	validation_0-logloss:0.42126
# [63]	validation_0-logloss:0.42122
# [64]	validation_0-logloss:0.42049
# [65]	validation_0-logloss:0.42047
# [66]	validation_0-logloss:0.42046
# [67]	validation_0-logloss:0.42077
# [68]	validation_0-logloss:0.42081
# [69]	validation_0-logloss:0.42082
# [70]	validation_0-logloss:0.42080
# [71]	validation_0-logloss:0.42075
# [72]	validation_0-logloss:0.42072
# [73]	validation_0-logloss:0.42069
# [74]	validation_0-logloss:0.42057
# [75]	validation_0-logloss:0.42059
# [76]	validation_0-logloss:0.42061
# [77]	validation_0-logloss:0.42060
# [78]	validation_0-logloss:0.42062
# [79]	validation_0-logloss:0.42009
# [80]	validation_0-logloss:0.42005
# [81]	validation_0-logloss:0.42032
# [82]	validation_0-logloss:0.42035
# [83]	validation_0-logloss:0.42030
# [84]	validation_0-logloss:0.42028
# [85]	validation_0-logloss:0.41910
# [86]	validation_0-logloss:0.41909
# [87]	validation_0-logloss:0.41909
# [88]	validation_0-logloss:0.41910
# [89]	validation_0-logloss:0.41908
# [90]	validation_0-logloss:0.41907
# [91]	validation_0-logloss:0.41904
# [92]	validation_0-logloss:0.41907
# [93]	validation_0-logloss:0.41910
# [94]	validation_0-logloss:0.41901
# [95]	validation_0-logloss:0.41856
# [96]	validation_0-logloss:0.41857
# [97]	validation_0-logloss:0.41858
# [98]	validation_0-logloss:0.41859
# [99]	validation_0-logloss:0.41791
# [100]	validation_0-logloss:0.41791
# [101]	validation_0-logloss:0.41793
# [102]	validation_0-logloss:0.41792
# [103]	validation_0-logloss:0.41794
# [104]	validation_0-logloss:0.41796
# [105]	validation_0-logloss:0.41797
# [106]	validation_0-logloss:0.41865
# [107]	validation_0-logloss:0.41865
# [108]	validation_0-logloss:0.41761
# [109]	validation_0-logloss:0.41761
# [110]	validation_0-logloss:0.41762
# [111]	validation_0-logloss:0.41760
# [112]	validation_0-logloss:0.41763
# [113]	validation_0-logloss:0.41765
# [114]	validation_0-logloss:0.41765
# [115]	validation_0-logloss:0.41766
# [116]	validation_0-logloss:0.41764
# [117]	validation_0-logloss:0.41764
# [118]	validation_0-logloss:0.41764
# [119]	validation_0-logloss:0.41764
# [120]	validation_0-logloss:0.41768
# [121]	validation_0-logloss:0.41830
# [122]	validation_0-logloss:0.41833
# [123]	validation_0-logloss:0.41730
# [124]	validation_0-logloss:0.41733
# [125]	validation_0-logloss:0.41733
# [126]	validation_0-logloss:0.41734
# [127]	validation_0-logloss:0.41731
# [128]	validation_0-logloss:0.41735
# [129]	validation_0-logloss:0.41729
# [130]	validation_0-logloss:0.41730
# [131]	validation_0-logloss:0.41727
# [132]	validation_0-logloss:0.41728
# [133]	validation_0-logloss:0.41725
# [134]	validation_0-logloss:0.41729
# [135]	validation_0-logloss:0.41645
# [136]	validation_0-logloss:0.41788
# [137]	validation_0-logloss:0.41703
# [138]	validation_0-logloss:0.41703
# [139]	validation_0-logloss:0.41702
# [140]	validation_0-logloss:0.41701
# [141]	validation_0-logloss:0.41702
# [142]	validation_0-logloss:0.41701
# [143]	validation_0-logloss:0.41701
# [144]	validation_0-logloss:0.41697
# [145]	validation_0-logloss:0.41697
# [146]	validation_0-logloss:0.41698
# [147]	validation_0-logloss:0.41701
# [148]	validation_0-logloss:0.41703
# [149]	validation_0-logloss:0.41701
# [150]	validation_0-logloss:0.41700
# [151]	validation_0-logloss:0.41583
# [152]	validation_0-logloss:0.41579
# [153]	validation_0-logloss:0.41578
# [154]	validation_0-logloss:0.41576
# [155]	validation_0-logloss:0.41577
# [156]	validation_0-logloss:0.41576
# [157]	validation_0-logloss:0.41513
# [158]	validation_0-logloss:0.41514
# [159]	validation_0-logloss:0.41515
# [160]	validation_0-logloss:0.41517
# [161]	validation_0-logloss:0.41518
# [162]	validation_0-logloss:0.41517
# [163]	validation_0-logloss:0.41519
# [164]	validation_0-logloss:0.41518
# [165]	validation_0-logloss:0.41519
# [166]	validation_0-logloss:0.41517
# [167]	validation_0-logloss:0.41517
# [168]	validation_0-logloss:0.41517
# [169]	validation_0-logloss:0.41516
# [170]	validation_0-logloss:0.41519
# [171]	validation_0-logloss:0.41517
# [172]	validation_0-logloss:0.41515
# [173]	validation_0-logloss:0.41518
# [174]	validation_0-logloss:0.41514
# [175]	validation_0-logloss:0.41511
# [176]	validation_0-logloss:0.41511
# [177]	validation_0-logloss:0.41513
# [178]	validation_0-logloss:0.41515
# [179]	validation_0-logloss:0.41516
# [180]	validation_0-logloss:0.41518
# [181]	validation_0-logloss:0.41519
# [182]	validation_0-logloss:0.41520
# [183]	validation_0-logloss:0.41521
# [184]	validation_0-logloss:0.41522
# [185]	validation_0-logloss:0.41522
# [186]	validation_0-logloss:0.41519
# [187]	validation_0-logloss:0.41519
# [188]	validation_0-logloss:0.41516
# [189]	validation_0-logloss:0.41516
# [190]	validation_0-logloss:0.41515
# [191]	validation_0-logloss:0.41515
# [192]	validation_0-logloss:0.41515
# [193]	validation_0-logloss:0.41516
# [194]	validation_0-logloss:0.41518
# [195]	validation_0-logloss:0.41516
# [196]	validation_0-logloss:0.41516
# [197]	validation_0-logloss:0.41518
# [198]	validation_0-logloss:0.41517
# [199]	validation_0-logloss:0.41519
# [200]	validation_0-logloss:0.41518
# [201]	validation_0-logloss:0.41493
# [202]	validation_0-logloss:0.41495
# [203]	validation_0-logloss:0.41492
# [204]	validation_0-logloss:0.41492
# [205]	validation_0-logloss:0.41492
# [206]	validation_0-logloss:0.41492
# [207]	validation_0-logloss:0.41491
# [208]	validation_0-logloss:0.41490
# [209]	validation_0-logloss:0.41493
# [210]	validation_0-logloss:0.41495
# [211]	validation_0-logloss:0.41498
# [212]	validation_0-logloss:0.41502
# [213]	validation_0-logloss:0.41500
# [214]	validation_0-logloss:0.41501
# [215]	validation_0-logloss:0.41500
# [216]	validation_0-logloss:0.41499
# [217]	validation_0-logloss:0.41498
# [218]	validation_0-logloss:0.41497
# [219]	validation_0-logloss:0.41495
# [220]	validation_0-logloss:0.41494
# [221]	validation_0-logloss:0.41495
# [222]	validation_0-logloss:0.41493
# [223]	validation_0-logloss:0.41492
# [224]	validation_0-logloss:0.41495
# [225]	validation_0-logloss:0.41496
# [226]	validation_0-logloss:0.41535
# [227]	validation_0-logloss:0.41536
# [228]	validation_0-logloss:0.41536
# [229]	validation_0-logloss:0.41537
# [230]	validation_0-logloss:0.41536
# [231]	validation_0-logloss:0.41538
# [232]	validation_0-logloss:0.41538
# [233]	validation_0-logloss:0.41538
# [234]	validation_0-logloss:0.41538
# [235]	validation_0-logloss:0.41481
# [236]	validation_0-logloss:0.41481
# [237]	validation_0-logloss:0.41483
# [238]	validation_0-logloss:0.41483
# [239]	validation_0-logloss:0.41486
# [240]	validation_0-logloss:0.41486
# [241]	validation_0-logloss:0.41486
# [242]	validation_0-logloss:0.41488
# [243]	validation_0-logloss:0.41488
# [244]	validation_0-logloss:0.41490
# [245]	validation_0-logloss:0.41491
# [246]	validation_0-logloss:0.41488
# [247]	validation_0-logloss:0.41487
# [248]	validation_0-logloss:0.41487
# [249]	validation_0-logloss:0.41485
# [250]	validation_0-logloss:0.41487
# [251]	validation_0-logloss:0.41486
# [252]	validation_0-logloss:0.41489
# [253]	validation_0-logloss:0.41488
# [254]	validation_0-logloss:0.41484
# [255]	validation_0-logloss:0.41485
# [256]	validation_0-logloss:0.41486
# [257]	validation_0-logloss:0.41485
# [258]	validation_0-logloss:0.41406
# [259]	validation_0-logloss:0.41413
# [260]	validation_0-logloss:0.41415
# [261]	validation_0-logloss:0.41415
# [262]	validation_0-logloss:0.41414
# [263]	validation_0-logloss:0.41413
# [264]	validation_0-logloss:0.41413
# [265]	validation_0-logloss:0.41409
# [266]	validation_0-logloss:0.41410
# [267]	validation_0-logloss:0.41407
# [268]	validation_0-logloss:0.41407
# [269]	validation_0-logloss:0.41408
# [270]	validation_0-logloss:0.41410
# [271]	validation_0-logloss:0.41407
# [272]	validation_0-logloss:0.41408
# [273]	validation_0-logloss:0.41409
# [274]	validation_0-logloss:0.41411
# [275]	validation_0-logloss:0.41409
# [276]	validation_0-logloss:0.41407
# [277]	validation_0-logloss:0.41409
# [278]	validation_0-logloss:0.41409
# [279]	validation_0-logloss:0.41406
# [280]	validation_0-logloss:0.41404
# [281]	validation_0-logloss:0.41405
# [282]	validation_0-logloss:0.41405
# [283]	validation_0-logloss:0.41404
# [284]	validation_0-logloss:0.41403
# [285]	validation_0-logloss:0.41400
# [286]	validation_0-logloss:0.41399
# [287]	validation_0-logloss:0.41402
# [288]	validation_0-logloss:0.41403
# [289]	validation_0-logloss:0.41402
# [290]	validation_0-logloss:0.41405
# [291]	validation_0-logloss:0.41408
# [292]	validation_0-logloss:0.41411
# [293]	validation_0-logloss:0.41412
# [294]	validation_0-logloss:0.41415
# [295]	validation_0-logloss:0.41411
# [296]	validation_0-logloss:0.41411
# [297]	validation_0-logloss:0.41407
# [298]	validation_0-logloss:0.41408
# [299]	validation_0-logloss:0.41409
# [300]	validation_0-logloss:0.41408
# [301]	validation_0-logloss:0.41409
# [302]	validation_0-logloss:0.41407
# [303]	validation_0-logloss:0.41408
# [304]	validation_0-logloss:0.41410
# [305]	validation_0-logloss:0.41412
# [306]	validation_0-logloss:0.41413
# [307]	validation_0-logloss:0.41413
# [308]	validation_0-logloss:0.41412
# [309]	validation_0-logloss:0.41415
# [310]	validation_0-logloss:0.41419
# [311]	validation_0-logloss:0.41418
# [312]	validation_0-logloss:0.41416
# [313]	validation_0-logloss:0.41413
# [314]	validation_0-logloss:0.41411
# [315]	validation_0-logloss:0.41412
# [316]	validation_0-logloss:0.41412
# [317]	validation_0-logloss:0.41411
# [318]	validation_0-logloss:0.41407
# [319]	validation_0-logloss:0.41408
# [320]	validation_0-logloss:0.41408
# [321]	validation_0-logloss:0.41409
# [322]	validation_0-logloss:0.41411
# [323]	validation_0-logloss:0.41410
# [324]	validation_0-logloss:0.41412
# [325]	validation_0-logloss:0.41410
# [326]	validation_0-logloss:0.41409
# [327]	validation_0-logloss:0.41407
# [328]	validation_0-logloss:0.41408
# [329]	validation_0-logloss:0.41407
# [330]	validation_0-logloss:0.41406
# [331]	validation_0-logloss:0.41404
# [332]	validation_0-logloss:0.41403
# [333]	validation_0-logloss:0.41401
# [334]	validation_0-logloss:0.41402
# [335]	validation_0-logloss:0.41492
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.7, device=None, early_stopping_rounds=50,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=4,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=7, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=575, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
predictions_xgmodel = diabetes_xgmodel.predict(X_test)

# Suponiendo que y_test y predictions son arrays/listas
accuracy_xgmodel = accuracy_score(y_test, predictions_xgmodel) * 100
print(f"Porcentaje de aciertos: {accuracy_xgmodel:.2f}%")
# Out:
# Porcentaje de aciertos: 80.73%
